# %%
# !pip install quantstats Riskfolio-Lib pyfolio-reloaded rmpy QuantLib NumPy SciPy pandas pymc statsmodels pulp scikit-learn
# Out:
# ...
#   Using cached quantstats-0.0.81-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached riskfolio_lib-7.2.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (18 kB)
# ...
#   Using cached pyfolio_reloaded-0.9.9-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached rmpy-1.2.4-py3-none-any.whl.metadata (64 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 31.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 102.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 66.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.3/981.3 kB 44.2 MB/s eta 0:00:00
# ...
