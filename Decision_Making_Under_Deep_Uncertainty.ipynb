# %%
# !pip install ema-workbench rhodium platypus-opt prim rsome SALib pandas numpy scipy matplotlib seaborn plotly altair scikit-learn joblib dask
# Out:
# ...
#   Using cached ema_workbench-2.5.3-py3-none-any.whl.metadata (8.1 kB)
# ...
#   Using cached Rhodium-1.4.0-py3-none-any.whl.metadata (47 kB)
# ...
#   Using cached Platypus_Opt-1.4.1-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached PRIM-1.0.0-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached rsome-1.3.1-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached salib-1.5.2-py3-none-any.whl.metadata (11 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 7.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.6/28.6 MB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.4/124.4 kB 16.5 MB/s eta 0:00:00
# ...
